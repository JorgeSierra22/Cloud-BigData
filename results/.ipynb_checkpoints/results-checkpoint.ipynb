# %%
#!pip install pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Los primeros datos que queremos analizar son las horas en las que se produjo el mayor numero de crimes

# %%
df = pd.read_csv("Hours/hours.csv", header=None, names=['Hora', 'Cantidad'])

# %%
df["Cantidad"].plot(kind="bar")

plt.show()

# %%
media_ponderada = (df['Hora'] * df['Cantidad']).sum() / df['Cantidad'].sum()
media_ponderada
# Out:
# 13.113745192475148

# %%
desviacion_estandar = df['Hora'].std()
desviacion_estandar
# Out:
# 7.0710678118654755

# %%
estadisticas = df['Cantidad'].describe()
print(estadisticas)
# Out:
# count        24.000000
# mean     330168.166667
# std      116858.789510
# min      109428.000000
# 25%      241718.000000
# 50%      364192.000000
# 75%      425142.500000
# max      454804.000000
# Name: Cantidad, dtype: float64

# %%
df.plot(x='Hora', y='Cantidad', marker='o')
plt.title('Tendencia de Crímenes por Hora del Día')
plt.xlabel('Hora del Día')
plt.ylabel('Cantidad')
plt.show()

# %%
df.boxplot(column='Cantidad', by='Hora')
plt.title('Boxplot de Crímenes por Hora del Día')
plt.suptitle('')  # Elimina el título automático
plt.xlabel('Hora del Día')
plt.ylabel('Cantidad')
plt.show()

# %%
# Calcular la media
media = df['Cantidad'].mean()

# Crear la gráfica de barras
plt.bar(df['Hora'], df['Cantidad'], color='blue', alpha=0.7, label='Cantidad')
plt.axhline(y=media, color='red', linestyle='--', label='Media')

# Configurar el título y las etiquetas
plt.title('Cantidad por Hora')
plt.xlabel('Hora')
plt.ylabel('Cantidad')

# Añadir una leyenda
plt.legend()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# **Conclusiones:**
#
#   Primero, con respecto a los resultados obtenidos sobre cuales son las horas en las que se producen mayores crímenes, gracias a estas gráficas, podemos ver que los delitos se concentran en la franja horaria comprendida entre las 18 y las 21 horas, a pesar de no ser el pico en cuanto a número (este se produce a las 12 de la noche). Esto nos hace ver que la mayoría de los crímenes en Chicago se producen en horas en las cuales la mayoría de la población está regresando de sus trabajos, y por lo tanto, hay una mayor actividad tanto en las calles, como en los restaurantes y el transporte, haciendo de estas 4 horas la oportunidad perfecta para llevar a cabo actividades delictivas.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %%
df1 = pd.read_csv("Streets/most_problematic_Street_by_district.csv", dtype={'District': str}, header=None, names=['District', "Street", 'Cantidad'])

# %%
df1= df1.dropna()

# %% [markdown]
# Con este dataframe, queremos estudiar la calle que ha causado más problemas a un

# %%
df1 = df1[df1['District'].str.startswith('0')]
print(df1)
# Out:
#    District         Street  Cantidad
# 1       001       STATE ST     71387
# 2       002      DR MARTIN     21219
# 3       003      DR MARTIN     26086
# 4       004   STONY ISLAND     16318
# 5       005   MICHIGAN AVE     21819
# 6       006        79TH ST     27057
# 7       007    ASHLAND AVE     22625
# 8       008     CICERO AVE     24806
# 9       009    ASHLAND AVE     15187
# 10      010      CERMAK RD     18214
# 11      011     MADISON ST     27562
# 12      012     MADISON ST     16252
# 13      014  MILWAUKEE AVE     23478
# 14      015     MADISON ST     20048
# 15      016       OHARE ST     20134
# 16      017    IRVING PARK     12118
# 17      018   MICHIGAN AVE     27023
# 18      019       CLARK ST     22895
# 19      020    SHERIDAN RD     12206
# 20      021    INDIANA AVE         4
# 21      022     HALSTED ST     16204
# 22      024    SHERIDAN RD     15127
# 23      025      NORTH AVE     31783
# 24      031       OHARE ST        60

# %%
df1.plot(kind="scatter", x="District", y="Street" )
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Pivota el DataFrame
pivot_df = df1.pivot(index='District', columns='Street', values='Cantidad')

# Crea la gráfica de barras apiladas
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 6))

# Mueve la leyenda a la parte superior derecha
ax.legend(loc='upper right')

# Configura etiquetas y título
plt.xlabel('Comisaría')
plt.ylabel('Cantidad')
plt.title('Cantidad por Calle y Comisaria')

# Muestra la gráfica
plt.show()

# %%
street_counts = df1['Street'].value_counts()
street_counts.head()
# Out:
# MADISON ST      3
# OHARE ST        2
# MICHIGAN AVE    2
# ASHLAND AVE     2
# SHERIDAN RD     2
# Name: Street, dtype: int64

# %%
# Crear la gráfica de barras
street_counts.plot(kind='bar', figsize=(10, 6), color='skyblue')

# Configurar el título y las etiquetas
plt.title('Número de Ocurrencias por Calle')
plt.xlabel('Calle')
plt.ylabel('Número de Ocurrencias')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Se puede apreciar que hay varias calles las cuales han sido atendidas por más de una comisaría. Si tratamos de comprender la razón de que haya calles reptidas podemos ver lo siguiente:
#
# Centrandonos en las calles que aprecen en más una ocasión:
#
# -Madison Street: Es una de las calles más largas de todo Chichago conectando el Este de la ciudad con el Oeste. En ella podemos encontrar el [United Center](UnitedCenter.jpg)(campo de baloncesto y hockey), el [Milennium Park](MillemiumPark.jpg) uno de los lugares más visitados de toda la ciudad debido a poseer el Pabellón Jay Pritzker, [Chase Tower](ChaseTower.jpg) un rascacielos de 60 pisos donde se encuentran las oficinas de algunas de las empresas más importantes de Chicago, [Civic Opera house](opera.jpg) la principal ópera de la cuidad entre otros muchos edificios, tanto de vivienda como comerciales.
#
# -O'Hare Street: Con respecto a esta calle cabe destacar que es la calle en la que se encuentra el aeropuerto de Chicago y por lo tanto, uno de los puntos más transitados de toda la cuidad, ya que El [Aeropuerto Internacional de Chicago O'Hare](O'hareAirport.jpg) (IATA: ORD) es uno de los aeropuertos más transitados de Estados Unidos y del mundo, con varios vuelos nacionales, internacionales e intercontinentales. Durante el 2022, 68.3 millones de pasajeros pasaron por el aeropuerto.
#
# Por lo tanto, podemos confirmar el pensamiento inicial que todos tenemos de que en lugares con grandes aglomeraciones de personas es donde más común es que se produzca un crimen, desde un simple robo de pertenencias o multas de tráfico, como otros más graves como consumo de drogas o agresiones.

# %% [markdown]
# Hasta el momento solo hemos llevado a cabo un análisis general para obtener las calles en las que más crimenes se han llevado a cabo, agrupando por la comisaría que atendió la denuncia en dicha calle, pero si se quisiera llevar a cabo un análisis más profundo de en que calles se han producido delitos de un tipo durante cierto año, se puede consultar el script grep_steets que simula el comando grep y encuentra y devuelve las calles con más delitos de un determinado tipo en un año dado.
#
# Los siguientes resultados por ejmeplo nos muestran las calles en las que más robos se produjeron en 2023:

# %%
df_THEFT_2023 = pd.read_csv("Streets/grep_THEFT_2023.csv", header=None, names=["Street", 'Cantidad'])
print(df_THEFT_2023.head(10))
# Out:
#          Street  Cantidad
# 0      STATE ST      1261
# 1  MICHIGAN AVE      1236
# 2      CLARK ST       917
# 3    HALSTED ST       719
# 4   ASHLAND AVE       596
# 5      BROADWAY       530
# 6   WESTERN AVE       458
# 7    KEDZIE AVE       412
# 8    CICERO AVE       406
# 9    PULASKI RD       406

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %%
df2 = pd.read_csv("District/year_district_crimes.csv",header=None, names=['Year',"District", 'Cantidad'])

# %%
suma = df2["Cantidad"].sum()
print(suma)
# Out:
# 7924036

# %%
df2= df2.dropna()

# %%
df2
# Out:
#      Year  District  Cantidad
# 0    2001       1.0     14861
# 1    2001       2.0     35407
# 2    2001       3.0     24312
# 3    2001       4.0     25121
# 4    2001       5.0     20007
# ..    ...       ...       ...
# 533  2023      20.0      4452
# 534  2023      22.0      6676
# 535  2023      24.0      7350
# 536  2023      25.0     11136
# 537  2023      31.0        12
#
# [532 rows x 3 columns]

# %%
df_max = pd.read_csv("District/most_crimes_in_district.csv", header=None, names=['Year', 'Cantidad'])
print(df_max)
# Out:
#     Year  Cantidad
# 0   2016     18654
# 1   2012     22724
# 2   2020     15056
# 3   2019     18720
# 4   2017     18069
# 5   2014     20671
# 6   2013     21956
# 7   2005     31353
# 8   2002     32100
# 9   2018     19275
# 10  2009     28639
# 11  2006     32270
# 12  2004     31404
# 13  2011     25384
# 14  2022     14812
# 15  2008     30859
# 16  2007     31107
# 17  2023     13575
# 18  2021     13957
# 19  2015     19535
# 20  2001     35407
# 21  2010     26531
# 22  2003     31709

# %%
# Combina los dos DataFrames en base al año y la cantidad máxima
result_df = pd.merge(df_max, df2, on=['Year', 'Cantidad'], how='left')

# Muestra el DataFrame resultante
print(result_df.sort_values(by='Year', ascending=True))
# Out:
#     Year  Cantidad  District
# 20  2001     35407       2.0
# 8   2002     32100       8.0
# 22  2003     31709       8.0
# 12  2004     31404       8.0
# 7   2005     31353       8.0
# 11  2006     32270       8.0
# 16  2007     31107       8.0
# 15  2008     30859       8.0
# 10  2009     28639       8.0
# 21  2010     26531       8.0
# 13  2011     25384       8.0
# 1   2012     22724       8.0
# 6   2013     21956      11.0
# 5   2014     20671      11.0
# 19  2015     19535      11.0
# 0   2016     18654      11.0
# 4   2017     18069      11.0
# 9   2018     19275      11.0
# 3   2019     18720      11.0
# 2   2020     15056      11.0
# 18  2021     13957      11.0
# 14  2022     14812       8.0
# 17  2023     13575       8.0

# %% [markdown]
# Que paso en 2013 que hizo que cambiara la tendencia de la comisaría que más crímenes atendía y que volvió a pasar en 2022 para volver a cambiar la tendencia

# %%
# Configuración del gráfico
plt.figure(figsize=(10, 6))

# Colorear puntos por distrito
colors = {2.0: 'blue', 8.0: 'green', 11.0: 'red'}
scatter = plt.scatter(result_df['Year'], result_df['Cantidad'], c=result_df['District'].map(colors), label=result_df['District'].astype(int))

# Configuración del gráfico
plt.title('Gráfico de Dispersión')
plt.xlabel('Año')
plt.ylabel('Cantidad')

# Ajustar la posición de la leyenda y el espacio entre la leyenda y la gráfica
plt.legend(title='District', bbox_to_anchor=(1.05, 1), loc='upper left')

# Añadir un ajuste para evitar que el gráfico se recorte
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df_media1 = df2.groupby('District')['Cantidad'].mean().reset_index()
df_media1
# Out:
#     District      Cantidad
# 0        1.0  14011.478261
# 1        2.0  16337.217391
# 2        3.0  17467.217391
# 3        4.0  19557.347826
# 4        5.0  15241.608696
# 5        6.0  20151.347826
# 6        7.0  19834.130435
# 7        8.0  23137.260870
# 8        9.0  16810.043478
# 9       10.0  14841.695652
# 10      11.0  22066.434783
# 11      12.0  17128.260870
# 12      14.0  13312.130435
# 13      15.0  14701.521739
# 14      16.0  10624.800000
# 15      17.0   9945.695652
# 16      18.0  15491.304348
# 17      19.0  15519.478261
# 18      20.0   6111.695652
# 19      21.0      2.000000
# 20      22.0  11279.043478
# 21      24.0  10437.478261
# 22      25.0  19579.217391
# 23      31.0     11.272727

# %%
df_media1.plot(x='District', y='Cantidad',kind="bar")
plt.title('Media desde 2001 hasta la actualidad')
plt.xlabel('Comisaría')
plt.show()

# %% [markdown]
# **Años de la pandemia:**

# %%
df_filtered = df2[df2['Year'] == 2019]

# %%
df_filtered.plot(x='District', y='Cantidad',kind="bar")
plt.xlabel('Comisaría')
plt.show()

# %%
df_filtered1 = df2[df2['Year'] == 2020]

# %%
df_filtered1.plot(x='District', y='Cantidad',kind="bar")
plt.xlabel('Comisaría')
plt.show()

# %%
df_filtered = df2[df2['Year'].isin([2019, 2020])]
df_filtered
# Out:
#      Year  District  Cantidad
# 421  2019       1.0     15304
# 422  2019       2.0     11258
# 423  2019       3.0     12516
# 424  2019       4.0     14063
# 425  2019       5.0     11381
# 426  2019       6.0     16891
# 427  2019       7.0     13736
# 428  2019       8.0     15734
# 429  2019       9.0     11026
# 430  2019      10.0     12501
# 431  2019      11.0     18720
# 432  2019      12.0     13192
# 433  2019      14.0      9293
# 434  2019      15.0     10015
# 435  2019      16.0      8322
# 436  2019      17.0      6758
# 437  2019      18.0     15179
# 438  2019      19.0     11841
# 439  2019      20.0      4386
# 440  2019      22.0      8261
# 441  2019      24.0      8024
# 442  2019      25.0     12963
# 443  2019      31.0         7
# 444  2020       1.0      8412
# 445  2020       2.0      9526
# 446  2020       3.0     11036
# 447  2020       4.0     12322
# 448  2020       5.0     10270
# 449  2020       6.0     14103
# 450  2020       7.0     11780
# ...

# %%
df_media = df_filtered.groupby('District')['Cantidad'].mean().reset_index()
df_media
# Out:
#     District  Cantidad
# 0        1.0   11858.0
# 1        2.0   10392.0
# 2        3.0   11776.0
# 3        4.0   13192.5
# 4        5.0   10825.5
# 5        6.0   15497.0
# 6        7.0   12758.0
# 7        8.0   14456.5
# 8        9.0   10159.5
# 9       10.0   11309.0
# 10      11.0   16888.0
# 11      12.0   11697.0
# 12      14.0    7983.0
# 13      15.0    9460.0
# 14      16.0    7952.5
# 15      17.0    6397.5
# 16      18.0   12026.0
# 17      19.0   10635.5
# 18      20.0    4243.0
# 19      22.0    7720.0
# 20      24.0    7432.0
# 21      25.0   12139.5
# 22      31.0       5.5

# %%
df_media.plot(x='District', y='Cantidad',kind="bar")
plt.xlabel('Comisaría')
plt.title('Media en los años de Pandemia')
plt.show()

# %%
#Comparar media de la pandemia con media general
print(df_media1)
# Out:
#     District      Cantidad
# 0        1.0  14011.478261
# 1        2.0  16337.217391
# 2        3.0  17467.217391
# 3        4.0  19557.347826
# 4        5.0  15241.608696
# 5        6.0  20151.347826
# 6        7.0  19834.130435
# 7        8.0  23137.260870
# 8        9.0  16810.043478
# 9       10.0  14841.695652
# 10      11.0  22066.434783
# 11      12.0  17128.260870
# 12      14.0  13312.130435
# 13      15.0  14701.521739
# 14      16.0  10624.800000
# 15      17.0   9945.695652
# 16      18.0  15491.304348
# 17      19.0  15519.478261
# 18      20.0   6111.695652
# 19      21.0      2.000000
# 20      22.0  11279.043478
# 21      24.0  10437.478261
# 22      25.0  19579.217391
# 23      31.0     11.272727

# %%
df_media1.plot(x='District', y='Cantidad',kind="bar")
plt.title('Media desde 2001 hasta la actualidad')
plt.xlabel('Comisaría')
plt.show()

# %%
merged_df = pd.merge(df_media, df_media1, on='District', suffixes=('_parcial', '_total'))
print(merged_df)
# Out:
#     District  Cantidad_parcial  Cantidad_total
# 0        1.0           11858.0    14011.478261
# 1        2.0           10392.0    16337.217391
# 2        3.0           11776.0    17467.217391
# 3        4.0           13192.5    19557.347826
# 4        5.0           10825.5    15241.608696
# 5        6.0           15497.0    20151.347826
# 6        7.0           12758.0    19834.130435
# 7        8.0           14456.5    23137.260870
# 8        9.0           10159.5    16810.043478
# 9       10.0           11309.0    14841.695652
# 10      11.0           16888.0    22066.434783
# 11      12.0           11697.0    17128.260870
# 12      14.0            7983.0    13312.130435
# 13      15.0            9460.0    14701.521739
# 14      16.0            7952.5    10624.800000
# 15      17.0            6397.5     9945.695652
# 16      18.0           12026.0    15491.304348
# 17      19.0           10635.5    15519.478261
# 18      20.0            4243.0     6111.695652
# ...

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 6))

# Barra para la media parcial
ax.bar(merged_df['District'], merged_df['Cantidad_parcial'], label='Media Parcial', color='blue', alpha=0.7)

# Barra para la media total
ax.bar(merged_df['District'], merged_df['Cantidad_total'], label='Media Total', color='skyblue', alpha=0.7)

# Configurar leyendas y etiquetas
ax.legend()
ax.set_xlabel('Comisaría')
ax.set_ylabel('Cantidad Media')
ax.set_title('Cantidad Media por Comisaría (Media Parcial vs Media Total)')

# Rotar las etiquetas del eje x para mejorar la legibilidad
plt.xticks(rotation=45, ha='right')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# **Conclusiones: **

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %%
df3 = pd.read_csv("TypeOfCrimes/typeOfCrime.csv", header=None, names=['Type',"Year", 'Cantidad'])

# %%
df3
# Out:
#                 Type  Year  Cantidad
# 0            BATTERY  2019     49517
# 1          NARCOTICS  2003     54288
# 2            BATTERY  2004     87136
# 3      OTHER OFFENSE  2003     31148
# 4    CRIMINAL DAMAGE  2013     30855
# ..               ...   ...       ...
# 715     NON-CRIMINAL  2022         5
# 716          BATTERY  2005     83964
# 717          BATTERY  2002     94153
# 718       KIDNAPPING  2020       120
# 719       KIDNAPPING  2022       117
#
# [720 rows x 3 columns]

# %%
# Agrupar por la columna 'Type' y sumar las cantidades
sum_by_type = df3.groupby('Type')['Cantidad'].sum().reset_index()

# Imprimir el resultado
print(sum_by_type)
# Out:
#                                  Type  Cantidad
# 0                               ARSON     13529
# 1                             ASSAULT    519475
# 2                             BATTERY   1446857
# 3                            BURGLARY    428181
# 4   CONCEALED CARRY LICENSE VIOLATION      1184
# 5                 CRIM SEXUAL ASSAULT     27561
# 6                     CRIMINAL DAMAGE    903262
# 7             CRIMINAL SEXUAL ASSAULT      7693
# 8                   CRIMINAL TRESPASS    216643
# 9                  DECEPTIVE PRACTICE    354223
# 10                  DOMESTIC VIOLENCE         1
# 11                           GAMBLING     14629
# 12                           HOMICIDE     12905
# 13                  HUMAN TRAFFICKING       104
# 14   INTERFERENCE WITH PUBLIC OFFICER     18682
# 15                       INTIMIDATION      4799
# 16                         KIDNAPPING      7306
# 17               LIQUOR LAW VIOLATION     14995
# 18                MOTOR VEHICLE THEFT    390528
# ...

# %%
suma = sum_by_type["Cantidad"].sum()
print(suma)
# Out:
# 7924036

# %%
sum_by_type.sort_values(by='Cantidad', ascending=False).head(5)
# Out:
#                Type  Cantidad
# 34            THEFT   1672545
# 2           BATTERY   1446857
# 6   CRIMINAL DAMAGE    903262
# 19        NARCOTICS    750218
# 1           ASSAULT    519475

# %%
sum_by_type.plot(x='Type', y='Cantidad',kind="bar")

plt.show()

# %%
df_sorted_Year = df3.sort_values(by='Year', ascending=True)
df_sorted_Year
# Out:
#                          Type  Year  Cantidad
# 405                  HOMICIDE  2001       667
# 315                  BURGLARY  2001     26014
# 323  OTHER NARCOTIC VIOLATION  2001         6
# 325        DECEPTIVE PRACTICE  2001     14949
# 345    PUBLIC PEACE VIOLATION  2001      2750
# ..                        ...   ...       ...
# 259                     ARSON  2023       407
# 263        DECEPTIVE PRACTICE  2023     12979
# 266         HUMAN TRAFFICKING  2023         8
# 90     PUBLIC PEACE VIOLATION  2023       704
# 45                SEX OFFENSE  2023      1099
#
# [720 rows x 3 columns]

# %%
#Crímenes más repetidos en 2023
df_filtered = df3[df3['Year'] == 2023]
df_2023 = df_filtered.sort_values(by='Cantidad', ascending=False)
print(df_2023.head())
# Out:
#                     Type  Year  Cantidad
# 386                THEFT  2023     45521
# 124              BATTERY  2023     35950
# 383      CRIMINAL DAMAGE  2023     24346
# 330  MOTOR VEHICLE THEFT  2023     23941
# 376              ASSAULT  2023     18364

# %%
#Crímenes más repetidos que sobrepasan una cantidad preocupante 
df_most_repeated_crimes = df3[df3['Cantidad'] >= 65000]
print(df_most_repeated_crimes.sort_values(by='Year', ascending=True))
# Out:
#         Type  Year  Cantidad
# 423    THEFT  2001     99277
# 222  BATTERY  2001     93463
# 717  BATTERY  2002     94153
# 311    THEFT  2002     98334
# 160  BATTERY  2003     88380
# 157    THEFT  2003     98876
# 2    BATTERY  2004     87136
# 21     THEFT  2004     95464
# 185    THEFT  2005     85684
# 716  BATTERY  2005     83964
# 212  BATTERY  2006     80666
# 219    THEFT  2006     86240
# 121    THEFT  2007     85156
# 247  BATTERY  2007     79593
# 71     THEFT  2008     88437
# 26   BATTERY  2008     75930
# 273    THEFT  2009     80976
# 284  BATTERY  2009     68460
# 352  BATTERY  2010     65401
# 183    THEFT  2010     76757
# 137    THEFT  2011     75153
# 409    THEFT  2012     75465
# 87     THEFT  2013     71535
# 243    THEFT  2018     65287

# %%
# Contar el número de veces que cada año está presente
year_counts = df_most_repeated_crimes['Year'].value_counts().sort_index()
print(year_counts)
# Out:
# 2001    2
# 2002    2
# 2003    2
# 2004    2
# 2005    2
# 2006    2
# 2007    2
# 2008    2
# 2009    2
# 2010    2
# 2011    1
# 2012    1
# 2013    1
# 2018    1
# Name: Year, dtype: int64

# %%
# Graficar el resultado
year_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Año')
plt.ylabel('Número de veces')
plt.title('Número de veces que cada Año está presente')
plt.show()

# %%
top_crimes_by_year = pd.DataFrame(columns=df3.columns)

# Obtener la lista de años únicos en tu DataFrame
unique_years = df3['Year'].unique()

# Iterar sobre cada año y obtener los 5 crímenes más repetidos
for year in unique_years:
    # Filtrar el DataFrame para el año actual
    df_filtered = df3[df3['Year'] == year]
    
    # Ordenar por 'Cantidad' de forma descendente
    df_year_top5 = df_filtered.sort_values(by='Cantidad', ascending=False).head(5)
    
    # Concatenar los resultados al DataFrame principal
    top_crimes_by_year = pd.concat([top_crimes_by_year, df_year_top5])

# Mostrar el DataFrame final con los 5 crímenes más repetidos por año
print(top_crimes_by_year)
# Out:
#                    Type  Year Cantidad
# 32                THEFT  2019    62492
# 0               BATTERY  2019    49517
# 175     CRIMINAL DAMAGE  2019    26681
# 25              ASSAULT  2019    20620
# 327  DECEPTIVE PRACTICE  2019    19068
# ..                  ...   ...      ...
# 183               THEFT  2010    76757
# 352             BATTERY  2010    65401
# 333           NARCOTICS  2010    43398
# 190     CRIMINAL DAMAGE  2010    40654
# 122            BURGLARY  2010    26422
#
# [115 rows x 3 columns]

# %%
import seaborn as sns 
sns.set(style="whitegrid")

# Configurar el tamaño del gráfico
plt.figure(figsize=(12, 8))

# Crear un gráfico de barras agrupado por año y tipo de crimen
sns.barplot(x='Type', y='Cantidad', hue='Year', data=top_crimes_by_year)

# Configurar etiquetas y título del gráfico
plt.xlabel('Tipo de Crimen')
plt.ylabel('Cantidad')
plt.title('Top 5 Crímenes Más Repetidos por Año')

# Ajustar la leyenda
plt.legend(title='Año', bbox_to_anchor=(1, 1))

# Rotar las etiquetas del eje x para mayor claridad
plt.xticks(rotation=45, ha='right')

# Mostrar el gráfico
plt.show()

# %%
top_crimes_by_year2001=top_crimes_by_year[top_crimes_by_year['Year'] == 2001]
print(top_crimes_by_year2001)
# Out:
#                 Type  Year Cantidad
# 423            THEFT  2001    99277
# 222          BATTERY  2001    93463
# 94   CRIMINAL DAMAGE  2001    55860
# 119        NARCOTICS  2001    50567
# 95           ASSAULT  2001    31384

# %%
top_crimes_theft=top_crimes_by_year[top_crimes_by_year['Type'] == "THEFT"]
print(top_crimes_theft.sort_values(by='Cantidad', ascending=False))
# Out:
#       Type  Year Cantidad
# 423  THEFT  2001    99277
# 157  THEFT  2003    98876
# 311  THEFT  2002    98334
# 21   THEFT  2004    95464
# 71   THEFT  2008    88437
# 219  THEFT  2006    86240
# 185  THEFT  2005    85684
# 121  THEFT  2007    85156
# 273  THEFT  2009    80976
# 183  THEFT  2010    76757
# 409  THEFT  2012    75465
# 137  THEFT  2011    75153
# 87   THEFT  2013    71535
# 243  THEFT  2018    65287
# 96   THEFT  2017    64386
# 32   THEFT  2019    62492
# 261  THEFT  2016    61621
# 161  THEFT  2014    61568
# 364  THEFT  2015    57350
# 31   THEFT  2022    54840
# 386  THEFT  2023    45521
# 304  THEFT  2020    41324
# 118  THEFT  2021    40802

# %%
top_crimes_theft.sort_values(by='Year', ascending=True).plot(x='Year', y='Cantidad', marker='o')

plt.show()

# %%
top_crimes_Battery=top_crimes_by_year[top_crimes_by_year['Type'] == "BATTERY"]
print(top_crimes_Battery.sort_values(by='Cantidad', ascending=False))
# Out:
#         Type  Year Cantidad
# 717  BATTERY  2002    94153
# 222  BATTERY  2001    93463
# 160  BATTERY  2003    88380
# 2    BATTERY  2004    87136
# 716  BATTERY  2005    83964
# 212  BATTERY  2006    80666
# 247  BATTERY  2007    79593
# 26   BATTERY  2008    75930
# 284  BATTERY  2009    68460
# 352  BATTERY  2010    65401
# 214  BATTERY  2011    60459
# 245  BATTERY  2012    59134
# 220  BATTERY  2013    54006
# 143  BATTERY  2016    50300
# 51   BATTERY  2018    49830
# 0    BATTERY  2019    49517
# 394  BATTERY  2014    49453
# 196  BATTERY  2017    49239
# 370  BATTERY  2015    48924
# 258  BATTERY  2020    41514
# 402  BATTERY  2022    40922
# 59   BATTERY  2021    40463
# 124  BATTERY  2023    35950

# %%
top_crimes_Battery.sort_values(by='Year', ascending=True).plot(x='Year', y='Cantidad', marker='o')

plt.show()

# %%
average_by_year = df3.groupby('Year')['Cantidad'].mean().reset_index()

# Muestra los resultados
print(average_by_year)
# Out:
#     Year      Cantidad
# 0   2001  15184.156250
# 1   2002  16226.933333
# 2   2003  15354.419355
# 3   2004  15647.533333
# 4   2005  15125.800000
# 5   2006  14939.300000
# 6   2007  14569.700000
# 7   2008  14730.517241
# 8   2009  13094.233333
# 9   2010  11952.161290
# 10  2011  12137.827586
# 11  2012  10849.258065
# 12  2013   9610.687500
# 13  2014   8111.647059
# 14  2015   8024.424242
# 15  2016   7936.470588
# 16  2017   8154.939394
# 17  2018   8149.272727
# 18  2019   8167.843750
# 19  2020   6431.393939
# 20  2021   6739.516129
# 21  2022   7710.322581
# 22  2023   6788.709677

# %%
average_by_year.plot(x='Year', y='Cantidad', marker='o')

plt.show()

# %% [markdown]
# Como conclusión obtenida, podemos ver que en Chicago se ha llevado un gran trabajo por parte tanto de los ciudadanos como de la policía y gobernantes para reducir el número de crimes que se realizan al año, es decir, reducir el índice de criminalidad anual, ya que como nos muestran las gráficas, se ve una clara tendencia hacia la disminución desde que se comenzo el estudio en 2001 hasta la actualidad en 2023.
#
# A pesar de haber reducido su cantidad, tanto el robo como las agresiones siguen siendo los tipos de delitos que más se cometen en Chicago. De hecho se puede ver que ambos aparecen entre los 3 delitos más cometidos en todos los años observados en el estudio. Esto nos puede ayudar a conocer cuales son los peligros más probables a los que nos podemos enfrentar como ciudadanos.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %%
df4 = pd.read_csv("TypeOfCrimes/cirmes_with_arrest.csv", header=None, names=['Type','Cantidad'])
print(df4)
# Out:
#                                  Type  Cantidad
# 0          OFFENSE INVOLVING CHILDREN     11175
# 1             CRIMINAL SEXUAL ASSAULT       561
# 2                            STALKING       670
# 3              PUBLIC PEACE VIOLATION     33195
# 4                           OBSCENITY       654
# 5                               ARSON      1670
# 6                   DOMESTIC VIOLENCE         1
# 7                            GAMBLING     14522
# 8                   CRIMINAL TRESPASS    150900
# 9                             ASSAULT    109023
# 10               LIQUOR LAW VIOLATION     14866
# 11                MOTOR VEHICLE THEFT     31319
# 12                              THEFT    185043
# 13                            BATTERY    316762
# 14                            ROBBERY     27645
# 15                           HOMICIDE      6083
# 16                          RITUALISM         3
# 17                   PUBLIC INDECENCY       194
# 18                CRIM SEXUAL ASSAULT      4388
# ...

# %%
suma2 = df4["Cantidad"].sum()
print(suma2)
# Out:
# 2051298

# %%
#Porcentaje de crimenes en los que se acaba produciendo un arresto
suma2/suma*100
# Out:
# 25.88703534411

# %% [markdown]
# Podemos ver que el total que representa los crímenes en los que se produjo un arresto es cercano al 25% con respecto al total. Esto nos indica que hay muchos delitos en los cuales el criminal acaba ileso, en cuanto a que no es atrapado, o porque el delito no era lo suficientemente grave como para necesitar que la policía usera una fuerza mayor. Esto se explica debido a que hay muchos crímenes como robos o multas de tráfico en los que el procentaje de arresto es muy bajo. A continuación, haremos un ananlisis más profundo sobre lo que significa este dato.

# %%
df4.sort_values(by='Cantidad', ascending=False).head(5)
# Out:
#                  Type  Cantidad
# 25          NARCOTICS    745556
# 13            BATTERY    316762
# 12              THEFT    185043
# 8   CRIMINAL TRESPASS    150900
# 9             ASSAULT    109023

# %%
df4['Porcentaje'] = (df4['Cantidad'] / suma2) * 100

# Crear un gráfico circular
plt.figure(figsize=(8, 8))
plt.pie(df4['Porcentaje'], labels=df4['Type'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Porcentaje de cada tipo')

# Mostrar el gráfico
plt.show()

# %%
df4.plot(x='Type', y='Cantidad',kind="bar")
plt.title('Crímenes con arresto total')
plt.show()

# %%
df_most_repeated_crimes_with_Arrest = df4[df4['Cantidad'] < 100000]
print(df_most_repeated_crimes_with_Arrest.sort_values(by='Cantidad', ascending=True))
# Out:
#                                  Type  Cantidad
# 6                   DOMESTIC VIOLENCE         1
# 32   NON-CRIMINAL (SUBJECT SPECIFIED)         3
# 16                          RITUALISM         3
# 34                     NON - CRIMINAL         6
# 35                  HUMAN TRAFFICKING        10
# 33                       NON-CRIMINAL        14
# 30           OTHER NARCOTIC VIOLATION       101
# 17                   PUBLIC INDECENCY       194
# 1             CRIMINAL SEXUAL ASSAULT       561
# 4                           OBSCENITY       654
# 2                            STALKING       670
# 19                       INTIMIDATION       719
# 27                         KIDNAPPING       785
# 22  CONCEALED CARRY LICENSE VIOLATION      1138
# 5                               ARSON      1670
# 18                CRIM SEXUAL ASSAULT      4388
# 15                           HOMICIDE      6083
# 23                        SEX OFFENSE      8413
# 0          OFFENSE INVOLVING CHILDREN     11175
# ...

# %%
suma_total = df_most_repeated_crimes_with_Arrest["Cantidad"].sum()
print(suma_total)
# Out:
# 544014

# %%
labels = df_most_repeated_crimes_with_Arrest['Type']
sizes = df_most_repeated_crimes_with_Arrest['Porcentaje']

# Crear un gráfico circular
plt.figure(figsize=(10, 10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Porcentaje de Cantidad por Tipo de Crimen')

# Mostrar el gráfico
plt.show()

# %%
suma_total/suma2*100
# Out:
# 26.520476303296743

# %%
df_most_repeated_crimes_with_Arrest.plot(x='Type', y='Cantidad',kind="bar")
plt.title('Crímenes con arrestos menores de 100000')
plt.show()

# %%
df_most_repeated_crimes_with_Arrest = df4[df4['Cantidad'] > 100000]
print(df_most_repeated_crimes_with_Arrest.sort_values(by='Cantidad', ascending=False))
# Out:
#                  Type  Cantidad
# 25          NARCOTICS    745556
# 13            BATTERY    316762
# 12              THEFT    185043
# 8   CRIMINAL TRESPASS    150900
# 9             ASSAULT    109023

# %%
labels = df_most_repeated_crimes_with_Arrest['Type']
sizes = df_most_repeated_crimes_with_Arrest['Porcentaje']

# Crear un gráfico circular
plt.figure(figsize=(10, 10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Porcentaje de Cantidad por Tipo de Crimen')

# Mostrar el gráfico
plt.show()

# %%
df_most_repeated_crimes_with_Arrest.plot(x='Type', y='Cantidad',kind="bar")
plt.title('Crímenes con arrestos mayores de 100000')
plt.show()

# %% [markdown]
# Gracias a esta gráfica podemos ver los cinco tipos de delitos que más arrestos han generado en el tiempo de nuestro estudio. Como podemos observar gracias al pie chart, el más abundante representando casi el 50% (de la gráfica particular o el 36% del global) son los que están relacionados con estupefacientes y otros tipos de drogas.

# %% [markdown]
# Hasta ahora, hemos visto solo cuales son los crímenes más comunes en los que se produce arresto por cantidad, pero es importante contextualizar cual es el porcentaje real con respecto al total de los crímenes que se han producido.

# %%
print(sum_by_type)
# Out:
#                                  Type  Cantidad
# 0                               ARSON     13529
# 1                             ASSAULT    519475
# 2                             BATTERY   1446857
# 3                            BURGLARY    428181
# 4   CONCEALED CARRY LICENSE VIOLATION      1184
# 5                 CRIM SEXUAL ASSAULT     27561
# 6                     CRIMINAL DAMAGE    903262
# 7             CRIMINAL SEXUAL ASSAULT      7693
# 8                   CRIMINAL TRESPASS    216643
# 9                  DECEPTIVE PRACTICE    354223
# 10                  DOMESTIC VIOLENCE         1
# 11                           GAMBLING     14629
# 12                           HOMICIDE     12905
# 13                  HUMAN TRAFFICKING       104
# 14   INTERFERENCE WITH PUBLIC OFFICER     18682
# 15                       INTIMIDATION      4799
# 16                         KIDNAPPING      7306
# 17               LIQUOR LAW VIOLATION     14995
# 18                MOTOR VEHICLE THEFT    390528
# ...

# %%
# Fusionar los DataFrames en base a la columna 'Type'
merged_df = pd.merge(df4, sum_by_type, on='Type', how='left', suffixes=('_param', '_total'))

# Calcular el porcentaje
merged_df['Porcentaje'] = (merged_df['Cantidad_param'] / merged_df['Cantidad_total']) * 100

# Imprimir el resultado
print(merged_df)
# Out:
#                                  Type  Cantidad_param  Cantidad_total  \
# 0          OFFENSE INVOLVING CHILDREN           11175           56765
# 1             CRIMINAL SEXUAL ASSAULT             561            7693
# 2                            STALKING             670            5078
# 3              PUBLIC PEACE VIOLATION           33195           52791
# 4                           OBSCENITY             654             839
# 5                               ARSON            1670           13529
# 6                   DOMESTIC VIOLENCE               1               1
# 7                            GAMBLING           14522           14629
# 8                   CRIMINAL TRESPASS          150900          216643
# 9                             ASSAULT          109023          519475
# 10               LIQUOR LAW VIOLATION           14866           14995
# 11                MOTOR VEHICLE THEFT           31319          390528
# ...

# %%
# Ordenar el DataFrame por porcentaje en orden descendente
merged_df = merged_df.sort_values(by='Porcentaje', ascending=False)

# Crear un gráfico de barras
plt.figure(figsize=(12, 8))
plt.bar(merged_df['Type'], merged_df['Porcentaje'], color='skyblue')
plt.xlabel('Tipo de Delito')
plt.ylabel('Porcentaje')
plt.title('Porcentaje de Delitos según el Parámetro')

# Rotar las etiquetas del eje x para mayor legibilidad
plt.xticks(rotation=45, ha='right')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# **Conclusiones**

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
df_2001_to_2006 = pd.read_csv("TypeOfCrimes/typeOfCrimes5/most_repeated_crime_2001-2006.csv", header=None, names=['Type','Intervalo','Cantidad'])
print(df_2001_to_2006)
# Out:
#                                  Type  Intervalo  Cantidad
# 0                     CRIMINAL DAMAGE  2001-2006    331648
# 1                               ARSON  2001-2006      5193
# 2             CRIMINAL SEXUAL ASSAULT  2001-2006       230
# 3                             ROBBERY  2001-2006    102289
# 4          OFFENSE INVOLVING CHILDREN  2001-2006     16692
# 5                   WEAPONS VIOLATION  2001-2006     24995
# 6    INTERFERENCE WITH PUBLIC OFFICER  2001-2006      3080
# 7                           RITUALISM  2001-2006        22
# 8                            GAMBLING  2001-2006      6561
# 9                             ASSAULT  2001-2006    174246
# 10                         KIDNAPPING  2001-2006      3677
# 11               LIQUOR LAW VIOLATION  2001-2006      7487
# 12                       PROSTITUTION  2001-2006     39282
# 13                           STALKING  2001-2006      1244
# 14                   PUBLIC INDECENCY  2001-2006        40
# ...

# %%
df_2007_to_2012 = pd.read_csv("TypeOfCrimes/typeOfCrimes5/most_repeated_crime_2007-2012.csv", header=None, names=['Type','Intervalo','Cantidad'])
print(df_2007_to_2012)
# Out:
#                                 Type  Intervalo  Cantidad
# 0                    CRIMINAL DAMAGE  2007-2012    268157
# 1                        SEX OFFENSE  2007-2012      7616
# 2                           BURGLARY  2007-2012    153730
# 3                  CRIMINAL TRESPASS  2007-2012     63136
# 4                          NARCOTICS  2007-2012    261994
# 5                           GAMBLING  2007-2012      5986
# 6                            ASSAULT  2007-2012    136470
# 7                      OTHER OFFENSE  2007-2012    138738
# 8                              ARSON  2007-2012      3467
# 9            CRIMINAL SEXUAL ASSAULT  2007-2012       320
# 10                          HOMICIDE  2007-2012      2813
# 11                           BATTERY  2007-2012    408977
# 12                      PROSTITUTION  2007-2012     22280
# 13                DECEPTIVE PRACTICE  2007-2012     82057
# 14               MOTOR VEHICLE THEFT  2007-2012    107845
# ...

# %%
df_2013_to_2018 = pd.read_csv("TypeOfCrimes/typeOfCrimes5/most_repeated_crime_2013-2018.csv", header=None, names=['Type','Intervalo','Cantidad'])
print(df_2013_to_2018)
# Out:
#                                  Type  Intervalo  Cantidad
# 0                     CRIMINAL DAMAGE  2013-2018    175217
# 1                             ROBBERY  2013-2018     64778
# 2             CRIMINAL SEXUAL ASSAULT  2013-2018       863
# 3              PUBLIC PEACE VIOLATION  2013-2018     12937
# 4                       OTHER OFFENSE  2013-2018    104476
# 5                            STALKING  2013-2018      1026
# 6                               THEFT  2013-2018    381747
# 7                               ARSON  2013-2018      2547
# 8                           NARCOTICS  2013-2018    125792
# 9                          KIDNAPPING  2013-2018      1216
# 10                  CRIMINAL TRESPASS  2013-2018     42105
# 11                       INTIMIDATION  2013-2018       827
# 12         OFFENSE INVOLVING CHILDREN  2013-2018     14810
# 13                           BURGLARY  2013-2018     84685
# 14                CRIM SEXUAL ASSAULT  2013-2018      8329
# ...

# %%
df_2019_to_2023 = pd.read_csv("TypeOfCrimes/typeOfCrimes5/most_repeated_crime_2019-2023.csv", header=None, names=['Type','Intervalo','Cantidad'])
print(df_2019_to_2023)
# Out:
#                                  Type  Intervalo  Cantidad
# 0                     CRIMINAL DAMAGE  2019-2023    128240
# 1                   HUMAN TRAFFICKING  2019-2023        54
# 2                           OBSCENITY  2019-2023       245
# 3                            BURGLARY  2019-2023     38581
# 4                               THEFT  2019-2023    244979
# 5                          KIDNAPPING  2019-2023       617
# 6    INTERFERENCE WITH PUBLIC OFFICER  2019-2023      3382
# 7                        PROSTITUTION  2019-2023      1533
# 8                         SEX OFFENSE  2019-2023      5747
# 9                             ROBBERY  2019-2023     41419
# 10                            BATTERY  2019-2023    208366
# 11  CONCEALED CARRY LICENSE VIOLATION  2019-2023       880
# 12                  CRIMINAL TRESPASS  2019-2023     22401
# 13                 DECEPTIVE PRACTICE  2019-2023     84371
# 14                      OTHER OFFENSE  2019-2023     70368
# ...

# %%
sum_by_type_2001_to_2006 = df_2001_to_2006['Cantidad'].sum()
print(sum_by_type_2001_to_2006)
# Out:
# 2820067

# %%
sum_by_type_2007_to_2012 = df_2007_to_2012['Cantidad'].sum()
print(sum_by_type_2007_to_2012)
# Out:
# 2315944

# %%
sum_by_type_2013_to_2018 = df_2013_to_2018['Cantidad'].sum()
print(sum_by_type_2013_to_2018)
# Out:
# 1656023

# %%
sum_by_type_2019_to_2023 = df_2019_to_2023['Cantidad'].sum()
print(sum_by_type_2019_to_2023)
# Out:
# 1132002

# %%
sumtotal = sum_by_type_2001_to_2006+sum_by_type_2007_to_2012+sum_by_type_2013_to_2018+sum_by_type_2019_to_2023
print(sumtotal)
# Out:
# 7924036

# %%
# Porcentajes
percentages = [
    sum_by_type_2001_to_2006 / sumtotal,
    sum_by_type_2007_to_2012 / sumtotal,
    sum_by_type_2013_to_2018 / sumtotal,
    sum_by_type_2019_to_2023 / sumtotal
]

# Etiquetas
labels = ['2001-2006', '2007-2012', '2013-2018', '2019-2023']

# Colores
colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue']

# Crear el gráfico de pastel
plt.figure(figsize=(8, 8))
plt.pie(percentages, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title('Distribución de crímenes por intervalo de años')
plt.show()

# %% [markdown]
# Podemos ver que Chicago ha ido evolucionando con respecto a la cantidad de crimenes cometidos y se puede ver que cada 5 años que pasan el número de crimenes se reduce en un 5-10% dependiendo del intervalo que consideremos.

# %% [markdown]
# Si queremos llevar un analisis más profundo sobre cada 5 años:

# %%
df_2001_to_2006.sort_values(by='Type', ascending=True).plot(x='Type', y='Cantidad',kind="bar")

plt.show()

# %%
df_2007_to_2012.sort_values(by='Type', ascending=True).plot(x='Type', y='Cantidad',kind="bar")

plt.show()

# %%
df_2013_to_2018.sort_values(by='Type', ascending=True).plot(x='Type', y='Cantidad',kind="bar")

plt.show()

# %%
df_2019_to_2023.sort_values(by='Type', ascending=True).plot(x='Type', y='Cantidad',kind="bar")

plt.show()
